# %%
import pandas as pd

df = pd.read_excel("data1.xlsx")
df
# Out:
#    DMU process  x1  x2  y1-O  y1-I  y2-O  y2-I   yf
# 0    A   total  11  14   2.0   NaN   2.0   NaN  1.0
# 1    A       1   3   5   2.0   2.0   NaN   NaN  NaN
# 2    A       2   4   3   NaN   NaN   2.0   1.0  NaN
# 3    A       f   4   6   NaN   2.0   NaN   1.0  1.0
# 4    B   total   7   7   1.0   NaN   1.0   NaN  1.0
# 5    B       1   2   3   1.0   1.0   NaN   NaN  NaN
# 6    B       2   2   1   NaN   NaN   1.0   1.0  NaN
# 7    B       f   3   3   NaN   1.0   NaN   1.0  1.0
# 8    C   total  11  14   1.0   NaN   1.0   NaN  2.0
# 9    C       1   3   4   1.0   1.0   NaN   NaN  NaN
# 10   C       2   5   3   NaN   NaN   1.0   1.0  NaN
# 11   C       f   3   7   NaN   1.0   NaN   1.0  2.0
# 12   D   total  14  14   2.0   NaN   3.0   NaN  1.0
# 13   D       1   4   6   2.0   1.0   NaN   NaN  NaN
# 14   D       2   5   5   NaN   NaN   3.0   1.0  NaN
# 15   D       f   5   3   NaN   1.0   NaN   1.0  1.0
# 16   E   total  14  15   3.0   NaN   2.0   NaN  3.0
# 17   E       1   5   6   3.0   1.0   NaN   NaN  NaN
# 18   E       2   5   4   NaN   NaN   2.0   2.0  NaN
# 19   E       f   4   5   NaN   1.0   NaN   2.0  3.0

# %%
processes = df['process'].unique().tolist()
processes.remove('total')  # Remove 'total' from the list of processes
processes
# Out:
# [1, 2, 'f']

# %%
DMU = df["DMU"].unique().tolist()
DMU
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
x_columns = [col for col in df.columns if col.startswith('x')]
x_columns
# Out:
# ['x1', 'x2']

# %%
Tot = df[df["process"]=="total"][["DMU"]+x_columns].set_index("DMU")
Tot
# Out:
#      x1  x2
# DMU
# A    11  14
# B     7   7
# C    11  14
# D    14  14
# E    14  15

# %%
res = df[df["process"]=="total"][["DMU","x1","x2","x3"]].set_index("DMU")
res
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 res = df[df["process"]=="total"][["DMU","x1","x2","x3"]].set_index("DMU")
#       2 res
#
# File ~/Documents/pyjobs/DEA/myvenv/lib/python3.12/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~/Documents/pyjobs/DEA/myvenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# File ~/Documents/pyjobs/DEA/myvenv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6252, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6249     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6251 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6252 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['x3'] not in index"

# %%
res.index.to_list()
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
res.to_dict()
# Out:
# {'x1': {'A': 32, 'B': 7, 'C': 11, 'D': 14, 'E': 33},
#  'x2': {'A': 41, 'B': 7, 'C': 14, 'D': 14, 'E': 39},
#  'x3': {'A': 60, 'B': 60, 'C': 60, 'D': 60, 'E': 120}}

# %%
res = df[df["process"]==1][["DMU","x1","x2","x3","y1-O","y1-I"]].set_index("DMU")
res.rename(columns={"y1-O":"yO","y1-I":"yI"},inplace=True)
res["TotyO"] = res["yO"]+res["yI"]
res = res.add_prefix('Proc1')

res
# Out:
#      Proc1x1  Proc1x2  Proc1x3  Proc1yO  Proc1yI  Proc1TotyO
# DMU
# A         20       16       30     50.0      2.0        52.0
# B          2        3       10   1000.0      1.0      1001.0
# C          3        4       10    200.0      1.0       201.0
# D          4        6       10    145.0      1.0       146.0
# E         24       30       70    930.0      1.0       931.0

# %%
res.to_dict()
# Out:
# {'Proc1x1': {'A': 20, 'B': 2, 'C': 3, 'D': 4, 'E': 24},
#  'Proc1x2': {'A': 16, 'B': 3, 'C': 4, 'D': 6, 'E': 30},
#  'Proc1x3': {'A': 30, 'B': 10, 'C': 10, 'D': 10, 'E': 70},
#  'Proc1yO': {'A': 50.0, 'B': 1000.0, 'C': 200.0, 'D': 145.0, 'E': 930.0},
#  'Proc1yI': {'A': 2.0, 'B': 1.0, 'C': 1.0, 'D': 1.0, 'E': 1.0},
#  'Proc1TotyO': {'A': 52.0, 'B': 1001.0, 'C': 201.0, 'D': 146.0, 'E': 931.0}}
